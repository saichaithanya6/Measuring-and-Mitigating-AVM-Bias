# %%
import pandas as pd
import numpy as np
data = pd.read_csv("train_with_feautures.csv")

# %%
k= data['logerror']
plt.hist(k)
# Out:
# (array([6.00000e+00, 4.00000e+00, 6.30000e+01, 3.20000e+02, 1.40105e+05,
#         2.92200e+03, 1.53000e+02, 7.80000e+01, 6.00000e+00, 4.00000e+00]),
#  array([-4.65542038, -3.66357847, -2.67173657, -1.67989467, -0.68805277,
#          0.30378914,  1.29563104,  2.28747294,  3.27931484,  4.27115675,
#          5.26299865]),
#  <BarContainer object of 10 artists>)

# %%
avg= data['logerror'].mean()
std= data['logerror'].std()
k= data['logerror']

# %%
import matplotlib.pyplot as plt


def normal_dist(k , avg , std):
    prob_density = (np.pi*std) * np.exp(-0.5*((k-avg)/std)**2)
    return prob_density

pdf = normal_dist(k,avg,std)
 
#Plotting the Results
plt.hist(pdf)
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
data1= data[data["logerror"] >= (avg+std)].parcelid

# %%
data_a= d2016[d2016.parcelid.isin(data1)]

# %%
list(data_a.columns)
# Out:
# ['parcelid',
#  'airconditioningtypeid',
#  'architecturalstyletypeid',
#  'basementsqft',
#  'bathroomcnt',
#  'bedroomcnt',
#  'buildingclasstypeid',
#  'buildingqualitytypeid',
#  'calculatedbathnbr',
#  'decktypeid',
#  'finishedfloor1squarefeet',
#  'calculatedfinishedsquarefeet',
#  'finishedsquarefeet12',
#  'finishedsquarefeet13',
#  'finishedsquarefeet15',
#  'finishedsquarefeet50',
#  'finishedsquarefeet6',
#  'fips',
#  'fireplacecnt',
#  'fullbathcnt',
#  'garagecarcnt',
#  'garagetotalsqft',
#  'hashottuborspa',
#  'heatingorsystemtypeid',
#  'latitude',
#  'longitude',
#  'lotsizesquarefeet',
#  'poolcnt',
#  'poolsizesum',
#  'pooltypeid10',
#  'pooltypeid2',
#  'pooltypeid7',
#  'propertycountylandusecode',
#  'propertylandusetypeid',
#  'propertyzoningdesc',
#  'rawcensustractandblock',
#  'regionidcity',
#  'regionidcounty',
#  'regionidneighborhood',
#  'regionidzip',
#  'roomcnt',
#  'storytypeid',
#  'threequarterbathnbr',
#  'typeconstructiontypeid',
# ...

# %%
data_a= data_a.drop(['parcelid', 'decktypeid', "fips",'finishedsquarefeet12', 'finishedsquarefeet13','finishedsquarefeet15',
 'finishedsquarefeet50',
 'finishedsquarefeet6',
 'fips',
 'fireplacecnt',
 'fullbathcnt',
 'hashottuborspa',
 'heatingorsystemtypeid',
 'lotsizesquarefeet',
 'poolcnt',
 'poolsizesum',
 'pooltypeid10',
 'pooltypeid2',
 'pooltypeid7',
 'propertyzoningdesc',
 'rawcensustractandblock',
 'regionidneighborhood',
 'roomcnt',
 'storytypeid',
 'threequarterbathnbr', 'typeconstructiontypeid'
 ], axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = data_a.corr()
round(corr_matrix,2)
print(corr_matrix)
# Out:
#                               airconditioningtypeid  architecturalstyletypeid  \
# airconditioningtypeid                      1.000000                 -0.447214
# architecturalstyletypeid                  -0.447214                  1.000000
# basementsqft                                    NaN                       NaN
# bathroomcnt                               -0.044766                  0.253898
# bedroomcnt                                 0.017651                 -0.104155
# buildingclasstypeid                             NaN                       NaN
# buildingqualitytypeid                           NaN                       NaN
# calculatedbathnbr                         -0.046185                  0.253898
# finishedfloor1squarefeet                        NaN                       NaN
# calculatedfinishedsquarefeet               0.010751                  0.065701
# garagecarcnt                               0.239523                 -0.191667
# ...

# %%
sns.heatmap(corr_matrix);
